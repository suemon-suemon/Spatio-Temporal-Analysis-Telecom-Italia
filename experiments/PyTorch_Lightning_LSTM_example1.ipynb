# %% [markdown]
# # Objective
#
# * Dataset from: https://www.kaggle.com/uciml/electric-power-consumption-data-set
# * Use PyTorchLightning to train and predict a model for 'Global_active_power'
#     * Create a Datset for the time series
#     * Create a Data Module
#     * Create a model
# * Use the information from the notebook 'DataAnalysis'
# * The notebook has been inspired by: https://www.kaggle.com/tartakovsky/pytorch-lightning-lstm-timeseries-clean-code

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
import pytorch_lightning as pl
from pytorch_lightning import Trainer, seed_everything
from pytorch_lightning.loggers import WandbLogger

import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# # Create a Dataset

# %%
class PowConDataSet(Dataset):
    def __init__(self, X, y, seq_len=1):
        
        self.X = torch.tensor(X).float()
        self.y = torch.tensor(y).float()
        self.seq_len = seq_len 
        
    def __getitem__(self, idx):
        return (self.X[idx:idx+self.seq_len-1], self.y[idx+self.seq_len-1])
        
    def __len__(self):
        return self.X.__len__() - (self.seq_len-1)

# %% [markdown]
# # Create a Data Module

# %%
class PowConDataModule(pl.LightningDataModule):
    
    def __init__(self, seq_len = 1, batch_size = 128, num_workers=8):
        super().__init__()
        self.seq_len = seq_len
        self.batch_size = batch_size
        self.num_workers = num_workers
    
    def setup(self, stage):
        '''
        * read Data
        * 'Date' and 'Time' columns are merged into 'date' index
        * convert all to float and delete nans
        * resampled to hourly intervals
        * define X (features) and y (lables)
        '''
        # read data
        filepath = '../data/household_power_consumption.txt'
        df_powcon = pd.read_csv(filepath, sep=';',
                        parse_dates={'date':['Date','Time']},
                        infer_datetime_format=True,
                        index_col='date')
        
        # change types to float (and all no number values to nan)
        for i in range(len(df_powcon.columns)):
            df_powcon.iloc[:,i] = pd.to_numeric(df_powcon.iloc[:,i], errors='coerce')
        
        # resamble to hourly means
        df_powcon = df_powcon.resample('h').mean()
        
        df_powcon.dropna(inplace=True)
        df_powcon = df_powcon.astype(float)
        
        # define features (X) and labels (y)
        y = df_powcon['Global_active_power'].values

        columns = ['Global_reactive_power', 'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2', 'Sub_metering_3']
        X = np.zeros((len(columns), len(y)))
        X = df_powcon[columns].values
        
        # train - valid - test splits
        X_tmp, self.X_test, y_tmp, self.y_test = train_test_split(X, y, shuffle=False, test_size=.2)
        self.X_train, self.X_val, self.y_train, self.y_val = train_test_split(X_tmp, y_tmp, shuffle=False, test_size=.25)
        print('train:', self.X_train.shape, self.y_train.shape)
        print('valid:', self.X_val.shape, self.y_val.shape)
        print('test:', self.X_test.shape, self.y_test.shape)


        # normalize each column
        scaler = StandardScaler()
        scaler.fit(self.X_train)
            
        self.X_train = scaler.transform(self.X_train)
        self.X_val = scaler.transform(self.X_val)
        self.X_test = scaler.transform(self.X_test)
        self.y_train = self.y_train.reshape(-1,1)
        self.y_val = self.y_val.reshape(-1,1)
        self.y_test = self.y_test.reshape(-1,1)
        
    def train_dataloader(self):
        '''
        * no further transformation necessary
        * wrap dataset in dataloader
        '''
        # create dataset
        train_dataset = PowConDataSet(self.X_train, self.y_train, seq_len=self.seq_len)
        
        # wrap dataset in dataloader
        train_dataloader = DataLoader(train_dataset, batch_size = self.batch_size, shuffle = False, 
                                      num_workers = self.num_workers)
        
        return train_dataloader
    
    def val_dataloader(self):
        # create dataset
        val_dataset = PowConDataSet(self.X_val, self.y_val, seq_len=self.seq_len)
        
        # wrap dataset in dataloader
        val_dataloader = DataLoader(val_dataset, batch_size = self.batch_size, shuffle = False,
                                   num_workers = self.num_workers)
        
        return val_dataloader
    
    def test_dataloader(self):
        # create dataset
        test_dataset = PowConDataSet(self.X_test, self.y_test, seq_len=self.seq_len)
        
        # wrap dataset in dataloader
        test_dataloader = DataLoader(test_dataset, batch_size = self.batch_size, shuffle = False,
                                   num_workers = self.num_workers)
        
        return test_dataloader

# %% [markdown]
# # Create a Model

# %%
class PowConModel(pl.LightningModule):
    
    def __init__(self, n_features, hidden_size, seq_len,
                num_layers, dropout,
                 learning_rate, criterion):
        super().__init__()
        self.n_features = n_features
        self.hidden_size = hidden_size
        self.seq_len = seq_len
        self.num_layers = num_layers
        self.dropout = dropout
        self.learning_rate = learning_rate
        self.criterion = criterion
        
        self.lstm = nn.LSTM(input_size=n_features,
                            hidden_size=hidden_size,
                            num_layers=num_layers,
                            dropout=dropout,
                            batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)
        
    def forward(self, x):
        lstm_out, _ = self.lstm(x) # lstm_out = (batch_size, seq_len, hidden_size)
        x = self.fc(lstm_out[:,-1])
        return x
    
    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=self.learning_rate)
        return optimizer
    
    def training_step(self, train_batch, batch_idx):
        x, y = train_batch
        y_hat = self.forward(x)
        loss = self.criterion(y_hat, y)
        #result = pl.TrainResult(minimize=loss)
        self.log('train_loss', loss, prog_bar=True)
        return loss

    def validation_step(self, val_batch, batch_idx):
        x, y = val_batch
        y_hat = self.forward(x)
        loss = self.criterion(y_hat, y)
        #result = pl.EvalResult(checkpoint_on=loss)
        self.log('val_loss', loss)
        return loss
    
    def test_step(self, test_batch, batch_idx):
        x, y = test_batch
        y_hat = self.forward(x)
        loss = self.criterion(y_hat,y)
        #result = pl.EvalResult()
        self.log('test_loss', loss)
        return loss

# %% [markdown]
# # Set Parameters

# %%
p = dict(
    seq_len = 24,
    batch_size = 128, 
    criterion = nn.MSELoss(),
    max_epochs = 5,
    n_features = 6,
    hidden_size = 10,
    num_layers = 1,
    dropout = 0.2,
    learning_rate = 0.01,
)

# %% [markdown]
# # Train

# %%
from fix_path import fix_python_path_if_working_locally
fix_python_path_if_working_locally()
from models.lstm import LSTMRegressor

seed_everything(42)
wandb_logger = WandbLogger(project="spatio-temporal prediction")


data_module = PowConDataModule(seq_len = p['seq_len'],
                           batch_size = p['batch_size'])

model = PowConModel(n_features = p['n_features'],
                    hidden_size = p['hidden_size'],
                    seq_len = p['seq_len'],
                    criterion = p['criterion'],
                    num_layers = p['num_layers'],
                    dropout = p['dropout'],
                    learning_rate = p['learning_rate'])

trainer = Trainer(max_epochs=p['max_epochs'], gpus=0)
trainer.fit(model, data_module)
# Out:
# /home/zzw/miniconda3/envs/timeseries/lib/python3.7/site-packages/torch/nn/modules/rnn.py:65: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# /home/zzw/miniconda3/envs/timeseries/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:1585: UserWarning: GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`.
#   "GPU available but not used. Set the gpus flag in your trainer `Trainer(gpus=1)` or script `--gpus=1`."
# /home/zzw/miniconda3/envs/timeseries/lib/python3.7/site-packages/pytorch_lightning/core/datamodule.py:474: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   fn(*args, **kwargs)
#
#   | Name      | Type    | Params
# --------------------------------------
# 0 | criterion | MSELoss | 0
# 1 | lstm      | LSTM    | 720
# 2 | fc        | Linear  | 11
# --------------------------------------
# 731       Trainable params
# 0         Non-trainable params
# 731       Total params
# 0.003     Total estimated model params size (MB)
# train: (20500, 6) (20500,)
# valid: (6834, 6) (6834,)
# test: (6834, 6) (6834,)
# Validation sanity check: 0it [00:00, ?it/s]
# tensor([1.5841]) tensor([0.3659])
# tensor([0.7418]) tensor([0.3887])
# Training: 0it [00:00, ?it/s]
# tensor([3.3260]) tensor([0.3822], grad_fn=<SelectBackward0>)
# tensor([1.6982]) tensor([0.4764], grad_fn=<SelectBackward0>)
# tensor([2.5357]) tensor([0.4981], grad_fn=<SelectBackward0>)
# tensor([1.4591]) tensor([0.4960], grad_fn=<SelectBackward0>)
# tensor([1.3605]) tensor([0.6612], grad_fn=<SelectBackward0>)
# tensor([2.6555]) tensor([0.6280], grad_fn=<SelectBackward0>)
# tensor([1.6331]) tensor([0.6202], grad_fn=<SelectBackward0>)
# tensor([1.8474]) tensor([0.7419], grad_fn=<SelectBackward0>)
# tensor([1.5726]) tensor([0.6845], grad_fn=<SelectBackward0>)
# tensor([2.5464]) tensor([1.2417], grad_fn=<SelectBackward0>)
# tensor([0.3206]) tensor([0.9861], grad_fn=<SelectBackward0>)
# tensor([2.5486]) tensor([1.0717], grad_fn=<SelectBackward0>)
# tensor([0.3284]) tensor([1.0648], grad_fn=<SelectBackward0>)
# tensor([0.2797]) tensor([0.8224], grad_fn=<SelectBackward0>)
# tensor([0.2694]) tensor([0.7906], grad_fn=<SelectBackward0>)
# tensor([1.4053]) tensor([1.4960], grad_fn=<SelectBackward0>)
# tensor([0.3082]) tensor([1.5247], grad_fn=<SelectBackward0>)
# tensor([3.0984]) tensor([1.8816], grad_fn=<SelectBackward0>)
# tensor([0.5428]) tensor([0.8968], grad_fn=<SelectBackward0>)
# tensor([0.3137]) tensor([1.8606], grad_fn=<SelectBackward0>)
# tensor([1.4110]) tensor([1.7989], grad_fn=<SelectBackward0>)
# tensor([0.2628]) tensor([1.5154], grad_fn=<SelectBackward0>)
# tensor([0.3115]) tensor([0.9853], grad_fn=<SelectBackward0>)
# tensor([1.2647]) tensor([1.1370], grad_fn=<SelectBackward0>)
# tensor([0.3944]) tensor([0.9112], grad_fn=<SelectBackward0>)
# tensor([0.2822]) tensor([1.3706], grad_fn=<SelectBackward0>)
# tensor([2.2957]) tensor([1.2467], grad_fn=<SelectBackward0>)
# tensor([0.4085]) tensor([0.7932], grad_fn=<SelectBackward0>)
# tensor([0.8342]) tensor([0.7253], grad_fn=<SelectBackward0>)
# tensor([1.9203]) tensor([1.6690], grad_fn=<SelectBackward0>)
# tensor([0.2953]) tensor([0.4927], grad_fn=<SelectBackward0>)
# tensor([3.7925]) tensor([2.0231], grad_fn=<SelectBackward0>)
# tensor([1.1968]) tensor([2.1538], grad_fn=<SelectBackward0>)
# tensor([0.1934]) tensor([0.3830], grad_fn=<SelectBackward0>)
# tensor([0.1710]) tensor([0.7738], grad_fn=<SelectBackward0>)
# tensor([0.5834]) tensor([0.5375], grad_fn=<SelectBackward0>)
# tensor([0.3091]) tensor([0.4935], grad_fn=<SelectBackward0>)
# tensor([0.2811]) tensor([0.4022], grad_fn=<SelectBackward0>)
# tensor([1.2429]) tensor([0.7078], grad_fn=<SelectBackward0>)
# tensor([0.4517]) tensor([0.4533], grad_fn=<SelectBackward0>)
# tensor([1.1163]) tensor([1.1614], grad_fn=<SelectBackward0>)
# tensor([0.3509]) tensor([1.4318], grad_fn=<SelectBackward0>)
# tensor([0.4950]) tensor([0.5561], grad_fn=<SelectBackward0>)
# tensor([0.2410]) tensor([0.7078], grad_fn=<SelectBackward0>)
# tensor([0.1641]) tensor([0.3502], grad_fn=<SelectBackward0>)
# tensor([1.3424]) tensor([0.3516], grad_fn=<SelectBackward0>)
# tensor([0.1685]) tensor([0.3554], grad_fn=<SelectBackward0>)
# tensor([1.6486]) tensor([1.5125], grad_fn=<SelectBackward0>)
# tensor([0.1573]) tensor([0.4608], grad_fn=<SelectBackward0>)
# tensor([0.2316]) tensor([0.4679], grad_fn=<SelectBackward0>)
# tensor([3.3181]) tensor([1.3206], grad_fn=<SelectBackward0>)
# tensor([1.4560]) tensor([0.3834], grad_fn=<SelectBackward0>)
# tensor([0.3492]) tensor([0.6367], grad_fn=<SelectBackward0>)
# tensor([0.8861]) tensor([0.8641], grad_fn=<SelectBackward0>)
# tensor([1.2007]) tensor([0.4246], grad_fn=<SelectBackward0>)
# tensor([0.5175]) tensor([0.4017], grad_fn=<SelectBackward0>)
# tensor([1.3191]) tensor([0.8439], grad_fn=<SelectBackward0>)
# tensor([0.3142]) tensor([0.3939], grad_fn=<SelectBackward0>)
# tensor([0.3592]) tensor([0.4515], grad_fn=<SelectBackward0>)
# tensor([0.2681]) tensor([0.4180], grad_fn=<SelectBackward0>)
# tensor([0.9410]) tensor([0.4535], grad_fn=<SelectBackward0>)
# tensor([1.0747]) tensor([1.2765], grad_fn=<SelectBackward0>)
# tensor([1.1946]) tensor([1.4267], grad_fn=<SelectBackward0>)
# tensor([0.8924]) tensor([0.4724], grad_fn=<SelectBackward0>)
# tensor([0.5530]) tensor([1.1641], grad_fn=<SelectBackward0>)
# tensor([3.6695]) tensor([2.4099], grad_fn=<SelectBackward0>)
# tensor([0.5998]) tensor([0.5314], grad_fn=<SelectBackward0>)
# tensor([1.0293]) tensor([0.5862], grad_fn=<SelectBackward0>)
# tensor([0.9424]) tensor([1.1480], grad_fn=<SelectBackward0>)
# tensor([0.3452]) tensor([0.6896], grad_fn=<SelectBackward0>)
# tensor([2.4636]) tensor([1.4491], grad_fn=<SelectBackward0>)
# tensor([2.2632]) tensor([1.0224], grad_fn=<SelectBackward0>)
# tensor([2.1243]) tensor([0.5678], grad_fn=<SelectBackward0>)
# tensor([1.2324]) tensor([2.3003], grad_fn=<SelectBackward0>)
# tensor([2.0730]) tensor([1.6716], grad_fn=<SelectBackward0>)
# tensor([0.8049]) tensor([0.9346], grad_fn=<SelectBackward0>)
# tensor([3.9548]) tensor([3.1283], grad_fn=<SelectBackward0>)
# tensor([1.1022]) tensor([2.5739], grad_fn=<SelectBackward0>)
# tensor([0.2763]) tensor([0.6361], grad_fn=<SelectBackward0>)
# tensor([0.3049]) tensor([1.8968], grad_fn=<SelectBackward0>)
# tensor([0.8683]) tensor([2.3716], grad_fn=<SelectBackward0>)
# tensor([0.4283]) tensor([1.3137], grad_fn=<SelectBackward0>)
# tensor([0.6106]) tensor([1.5098], grad_fn=<SelectBackward0>)
# tensor([1.3046]) tensor([2.6744], grad_fn=<SelectBackward0>)
# tensor([0.6244]) tensor([0.7705], grad_fn=<SelectBackward0>)
# tensor([0.3845]) tensor([1.5684], grad_fn=<SelectBackward0>)
# tensor([1.8439]) tensor([2.5115], grad_fn=<SelectBackward0>)
# tensor([0.8468]) tensor([0.6734], grad_fn=<SelectBackward0>)
# tensor([0.3446]) tensor([1.5393], grad_fn=<SelectBackward0>)
# tensor([1.4109]) tensor([1.8181], grad_fn=<SelectBackward0>)
# tensor([0.3475]) tensor([0.8843], grad_fn=<SelectBackward0>)
# tensor([1.5377]) tensor([1.7052], grad_fn=<SelectBackward0>)
# tensor([1.7076]) tensor([2.5609], grad_fn=<SelectBackward0>)
# tensor([0.3269]) tensor([0.8608], grad_fn=<SelectBackward0>)
# tensor([0.5930]) tensor([1.0893], grad_fn=<SelectBackward0>)
# tensor([0.8152]) tensor([1.8999], grad_fn=<SelectBackward0>)
# tensor([0.7317]) tensor([0.8473], grad_fn=<SelectBackward0>)
# tensor([1.3405]) tensor([1.7294], grad_fn=<SelectBackward0>)
# tensor([3.9782]) tensor([2.1402], grad_fn=<SelectBackward0>)
# tensor([0.5103]) tensor([0.8449], grad_fn=<SelectBackward0>)
# tensor([0.3928]) tensor([1.0162], grad_fn=<SelectBackward0>)
# tensor([0.7679]) tensor([1.8395], grad_fn=<SelectBackward0>)
# tensor([1.5332]) tensor([0.7262], grad_fn=<SelectBackward0>)
# tensor([3.1586]) tensor([1.7643], grad_fn=<SelectBackward0>)
# tensor([0.9122]) tensor([1.5509], grad_fn=<SelectBackward0>)
# tensor([1.3541]) tensor([0.7088], grad_fn=<SelectBackward0>)
# tensor([0.3488]) tensor([0.7191], grad_fn=<SelectBackward0>)
# tensor([1.5712]) tensor([0.6638], grad_fn=<SelectBackward0>)
# tensor([1.4618]) tensor([0.6605], grad_fn=<SelectBackward0>)
# tensor([0.4632]) tensor([0.7216], grad_fn=<SelectBackward0>)
# tensor([0.5114]) tensor([0.7481], grad_fn=<SelectBackward0>)
# tensor([0.3034]) tensor([0.6545], grad_fn=<SelectBackward0>)
# tensor([0.2159]) tensor([0.6195], grad_fn=<SelectBackward0>)
# tensor([0.2055]) tensor([0.5808], grad_fn=<SelectBackward0>)
# tensor([0.1607]) tensor([0.5714], grad_fn=<SelectBackward0>)
# tensor([0.1718]) tensor([0.5142], grad_fn=<SelectBackward0>)
# tensor([0.1873]) tensor([0.5846], grad_fn=<SelectBackward0>)
# tensor([0.2668]) tensor([0.5480], grad_fn=<SelectBackward0>)
# tensor([0.3755]) tensor([0.9368], grad_fn=<SelectBackward0>)
# tensor([1.1411]) tensor([0.8763], grad_fn=<SelectBackward0>)
# tensor([0.6843]) tensor([0.7381], grad_fn=<SelectBackward0>)
# tensor([0.3017]) tensor([0.4791], grad_fn=<SelectBackward0>)
# tensor([1.9547]) tensor([1.5662], grad_fn=<SelectBackward0>)
# tensor([0.3022]) tensor([0.8831], grad_fn=<SelectBackward0>)
# tensor([1.7548]) tensor([0.8145], grad_fn=<SelectBackward0>)
# tensor([1.0397]) tensor([1.1569], grad_fn=<SelectBackward0>)
# tensor([1.2517]) tensor([0.7061], grad_fn=<SelectBackward0>)
# tensor([0.2734]) tensor([0.4472], grad_fn=<SelectBackward0>)
# tensor([0.4784]) tensor([0.5151], grad_fn=<SelectBackward0>)
# tensor([0.9900]) tensor([0.6934], grad_fn=<SelectBackward0>)
# tensor([2.2233]) tensor([1.5012], grad_fn=<SelectBackward0>)
# tensor([1.0582]) tensor([0.8800], grad_fn=<SelectBackward0>)
# tensor([0.3456]) tensor([0.7663], grad_fn=<SelectBackward0>)
# tensor([0.5393]) tensor([0.8285], grad_fn=<SelectBackward0>)
# tensor([1.3223]) tensor([0.8844], grad_fn=<SelectBackward0>)
# tensor([0.7666]) tensor([0.4800], grad_fn=<SelectBackward0>)
# tensor([1.8038]) tensor([1.3722], grad_fn=<SelectBackward0>)
# tensor([2.3857]) tensor([1.7317], grad_fn=<SelectBackward0>)
# tensor([0.2826]) tensor([0.4759], grad_fn=<SelectBackward0>)
# tensor([1.1063]) tensor([0.9350], grad_fn=<SelectBackward0>)
# tensor([0.5431]) tensor([2.3946], grad_fn=<SelectBackward0>)
# tensor([1.0980]) tensor([0.4968], grad_fn=<SelectBackward0>)
# tensor([0.3431]) tensor([1.0705], grad_fn=<SelectBackward0>)
# tensor([1.5166]) tensor([1.1585], grad_fn=<SelectBackward0>)
# tensor([0.8261]) tensor([0.5361], grad_fn=<SelectBackward0>)
# tensor([2.7053]) tensor([2.1034], grad_fn=<SelectBackward0>)
# tensor([0.8102]) tensor([0.8604], grad_fn=<SelectBackward0>)
# tensor([1.2882]) tensor([0.6133], grad_fn=<SelectBackward0>)
# tensor([0.3690]) tensor([0.7012], grad_fn=<SelectBackward0>)
# tensor([0.3567]) tensor([1.3679], grad_fn=<SelectBackward0>)
# tensor([0.4401]) tensor([0.7042], grad_fn=<SelectBackward0>)
# tensor([1.3535]) tensor([1.1058], grad_fn=<SelectBackward0>)
# tensor([0.8910]) tensor([2.1771], grad_fn=<SelectBackward0>)
# tensor([0.2679]) tensor([0.7083], grad_fn=<SelectBackward0>)
# tensor([0.4002]) tensor([1.4413], grad_fn=<SelectBackward0>)
# tensor([2.1553]) tensor([1.8493], grad_fn=<SelectBackward0>)
# tensor([1.6487]) tensor([0.8151], grad_fn=<SelectBackward0>)
# tensor([0.4262]) tensor([1.5675], grad_fn=<SelectBackward0>)
# tensor([1.7996]) tensor([1.6122], grad_fn=<SelectBackward0>)
# tensor([0.3917]) tensor([0.8899], grad_fn=<SelectBackward0>)
# Validating: 0it [00:00, ?it/s]
# tensor([1.5841]) tensor([1.7833])
# tensor([0.7418]) tensor([1.4179])
# tensor([0.4031]) tensor([0.6920])
# tensor([1.5727]) tensor([1.7069])
# tensor([0.4598]) tensor([0.7868])
# tensor([0.3609]) tensor([1.0276])
# tensor([0.8862]) tensor([1.6712])
# tensor([0.6603]) tensor([1.4622])
# tensor([0.3223]) tensor([0.7597])
# tensor([1.4837]) tensor([1.7010])
# tensor([0.3734]) tensor([1.0690])
# tensor([1.5351]) tensor([0.9243])
# tensor([0.5969]) tensor([0.7970])
# tensor([0.3928]) tensor([0.8763])
# tensor([3.0504]) tensor([1.4427])
# tensor([0.2807]) tensor([0.6867])
# tensor([1.8418]) tensor([1.5975])
# tensor([0.3923]) tensor([0.8049])
# tensor([0.7017]) tensor([0.7609])
# tensor([0.2618]) tensor([0.7189])
# tensor([0.2907]) tensor([0.7162])
# tensor([0.3284]) tensor([1.1210])
# tensor([0.3462]) tensor([0.8687])
# tensor([1.0652]) tensor([1.5424])
# tensor([0.5058]) tensor([0.7882])
# tensor([1.7689]) tensor([2.1702])
# tensor([1.4982]) tensor([2.1850])
# tensor([0.8277]) tensor([1.2586])
# tensor([0.3212]) tensor([1.1375])
# tensor([0.4049]) tensor([0.7540])
# tensor([1.1356]) tensor([0.8009])
# tensor([0.9091]) tensor([0.8329])
# tensor([1.0740]) tensor([1.1374])
# tensor([0.3086]) tensor([0.7371])
# tensor([1.2093]) tensor([0.8642])
# tensor([1.2882]) tensor([2.4066])
# tensor([0.3483]) tensor([0.7006])
# tensor([2.4853]) tensor([2.4948])
# tensor([1.4589]) tensor([1.3388])
# tensor([0.4760]) tensor([0.6808])
# tensor([0.7877]) tensor([0.7961])
# tensor([1.1403]) tensor([1.5929])
# tensor([0.6107]) tensor([0.7027])
# tensor([1.4034]) tensor([1.4049])
# tensor([1.7050]) tensor([1.8301])
# tensor([0.5727]) tensor([0.6169])
# tensor([1.7107]) tensor([1.7948])
# tensor([2.0344]) tensor([2.6738])
# tensor([1.6150]) tensor([0.6091])
# tensor([0.4084]) tensor([0.6694])
# tensor([0.2961]) tensor([0.6932])
# tensor([2.9658]) tensor([1.9795])
# tensor([1.8160]) tensor([1.6222])
# tensor([1.4021]) tensor([1.4397])
# tensor([3.3260]) tensor([2.3395], grad_fn=<SelectBackward0>)
# tensor([1.6982]) tensor([1.8239], grad_fn=<SelectBackward0>)
# tensor([2.5357]) tensor([1.1587], grad_fn=<SelectBackward0>)
# tensor([1.4591]) tensor([1.4200], grad_fn=<SelectBackward0>)
# tensor([1.3605]) tensor([1.4180], grad_fn=<SelectBackward0>)
# tensor([2.6555]) tensor([1.7243], grad_fn=<SelectBackward0>)
# tensor([1.6331]) tensor([0.8729], grad_fn=<SelectBackward0>)
# tensor([1.8474]) tensor([1.1938], grad_fn=<SelectBackward0>)
# tensor([1.5726]) tensor([1.3831], grad_fn=<SelectBackward0>)
# tensor([2.5464]) tensor([2.2451], grad_fn=<SelectBackward0>)
# tensor([0.3206]) tensor([0.9703], grad_fn=<SelectBackward0>)
# tensor([2.5486]) tensor([2.3942], grad_fn=<SelectBackward0>)
# tensor([0.3284]) tensor([0.6499], grad_fn=<SelectBackward0>)
# tensor([0.2797]) tensor([0.6581], grad_fn=<SelectBackward0>)
# tensor([0.2694]) tensor([0.6638], grad_fn=<SelectBackward0>)
# tensor([1.4053]) tensor([1.2852], grad_fn=<SelectBackward0>)
# tensor([0.3082]) tensor([0.5122], grad_fn=<SelectBackward0>)
# tensor([3.0984]) tensor([2.3018], grad_fn=<SelectBackward0>)
# tensor([0.5428]) tensor([0.5721], grad_fn=<SelectBackward0>)
# tensor([0.3137]) tensor([0.7800], grad_fn=<SelectBackward0>)
# tensor([1.4110]) tensor([2.8036], grad_fn=<SelectBackward0>)
# tensor([0.2628]) tensor([0.8638], grad_fn=<SelectBackward0>)
# tensor([0.3115]) tensor([0.5697], grad_fn=<SelectBackward0>)
# tensor([1.2647]) tensor([1.6663], grad_fn=<SelectBackward0>)
# tensor([0.3944]) tensor([0.8297], grad_fn=<SelectBackward0>)
# tensor([0.2822]) tensor([1.0589], grad_fn=<SelectBackward0>)
# tensor([2.2957]) tensor([0.6465], grad_fn=<SelectBackward0>)
# tensor([0.4085]) tensor([0.5890], grad_fn=<SelectBackward0>)
# tensor([0.8342]) tensor([0.6094], grad_fn=<SelectBackward0>)
# tensor([1.9203]) tensor([1.5993], grad_fn=<SelectBackward0>)
# tensor([0.2953]) tensor([0.5799], grad_fn=<SelectBackward0>)
# tensor([3.7925]) tensor([2.0910], grad_fn=<SelectBackward0>)
# tensor([1.1968]) tensor([3.0664], grad_fn=<SelectBackward0>)
# tensor([0.1934]) tensor([0.3960], grad_fn=<SelectBackward0>)
# tensor([0.1710]) tensor([1.0234], grad_fn=<SelectBackward0>)
# tensor([0.5834]) tensor([0.6034], grad_fn=<SelectBackward0>)
# tensor([0.3091]) tensor([0.5054], grad_fn=<SelectBackward0>)
# tensor([0.2811]) tensor([0.3432], grad_fn=<SelectBackward0>)
# tensor([1.2429]) tensor([0.8995], grad_fn=<SelectBackward0>)
# tensor([0.4517]) tensor([0.4512], grad_fn=<SelectBackward0>)
# tensor([1.1163]) tensor([0.5184], grad_fn=<SelectBackward0>)
# tensor([0.3509]) tensor([1.6373], grad_fn=<SelectBackward0>)
# tensor([0.4950]) tensor([0.5656], grad_fn=<SelectBackward0>)
# tensor([0.2410]) tensor([0.4464], grad_fn=<SelectBackward0>)
# tensor([0.1641]) tensor([0.3454], grad_fn=<SelectBackward0>)
# tensor([1.3424]) tensor([0.3623], grad_fn=<SelectBackward0>)
# tensor([0.1685]) tensor([0.3563], grad_fn=<SelectBackward0>)
# tensor([1.6486]) tensor([2.1405], grad_fn=<SelectBackward0>)
# tensor([0.1573]) tensor([0.4743], grad_fn=<SelectBackward0>)
# tensor([0.2316]) tensor([0.2354], grad_fn=<SelectBackward0>)
# tensor([3.3181]) tensor([2.4323], grad_fn=<SelectBackward0>)
# tensor([1.4560]) tensor([0.4538], grad_fn=<SelectBackward0>)
# tensor([0.3492]) tensor([0.4622], grad_fn=<SelectBackward0>)
# tensor([0.8861]) tensor([1.1968], grad_fn=<SelectBackward0>)
# tensor([1.2007]) tensor([0.3786], grad_fn=<SelectBackward0>)
# tensor([0.5175]) tensor([0.4758], grad_fn=<SelectBackward0>)
# tensor([1.3191]) tensor([1.3726], grad_fn=<SelectBackward0>)
# tensor([0.3142]) tensor([0.4559], grad_fn=<SelectBackward0>)
# tensor([0.3592]) tensor([0.3584], grad_fn=<SelectBackward0>)
# tensor([0.2681]) tensor([0.4526], grad_fn=<SelectBackward0>)
# tensor([0.9410]) tensor([0.5673], grad_fn=<SelectBackward0>)
# tensor([1.0747]) tensor([1.2528], grad_fn=<SelectBackward0>)
# tensor([1.1946]) tensor([1.7260], grad_fn=<SelectBackward0>)
# tensor([0.8924]) tensor([0.5385], grad_fn=<SelectBackward0>)
# tensor([0.5530]) tensor([1.2402], grad_fn=<SelectBackward0>)
# tensor([3.6695]) tensor([3.2963], grad_fn=<SelectBackward0>)
# tensor([0.5998]) tensor([0.5776], grad_fn=<SelectBackward0>)
# tensor([1.0293]) tensor([0.8217], grad_fn=<SelectBackward0>)
# tensor([0.9424]) tensor([1.9688], grad_fn=<SelectBackward0>)
# tensor([0.3452]) tensor([0.9674], grad_fn=<SelectBackward0>)
# tensor([2.4636]) tensor([1.4610], grad_fn=<SelectBackward0>)
# tensor([2.2632]) tensor([1.6999], grad_fn=<SelectBackward0>)
# tensor([2.1243]) tensor([0.6116], grad_fn=<SelectBackward0>)
# tensor([1.2324]) tensor([2.0877], grad_fn=<SelectBackward0>)
# tensor([2.0730]) tensor([2.3239], grad_fn=<SelectBackward0>)
# tensor([0.8049]) tensor([1.2934], grad_fn=<SelectBackward0>)
# tensor([3.9548]) tensor([3.1027], grad_fn=<SelectBackward0>)
# tensor([1.1022]) tensor([2.9189], grad_fn=<SelectBackward0>)
# tensor([0.2763]) tensor([0.6916], grad_fn=<SelectBackward0>)
# tensor([0.3049]) tensor([1.4101], grad_fn=<SelectBackward0>)
# tensor([0.8683]) tensor([2.3395], grad_fn=<SelectBackward0>)
# tensor([0.4283]) tensor([1.4411], grad_fn=<SelectBackward0>)
# tensor([0.6106]) tensor([1.5345], grad_fn=<SelectBackward0>)
# tensor([1.3046]) tensor([2.5197], grad_fn=<SelectBackward0>)
# tensor([0.6244]) tensor([0.5389], grad_fn=<SelectBackward0>)
# tensor([0.3845]) tensor([0.9883], grad_fn=<SelectBackward0>)
# tensor([1.8439]) tensor([2.2093], grad_fn=<SelectBackward0>)
# tensor([0.8468]) tensor([0.6173], grad_fn=<SelectBackward0>)
# tensor([0.3446]) tensor([1.1015], grad_fn=<SelectBackward0>)
# tensor([1.4109]) tensor([2.1109], grad_fn=<SelectBackward0>)
# tensor([0.3475]) tensor([0.5821], grad_fn=<SelectBackward0>)
# tensor([1.5377]) tensor([1.3582], grad_fn=<SelectBackward0>)
# tensor([1.7076]) tensor([2.7139], grad_fn=<SelectBackward0>)
# tensor([0.3269]) tensor([0.7941], grad_fn=<SelectBackward0>)
# tensor([0.5930]) tensor([1.0589], grad_fn=<SelectBackward0>)
# tensor([0.8152]) tensor([1.8221], grad_fn=<SelectBackward0>)
# tensor([0.7317]) tensor([0.7426], grad_fn=<SelectBackward0>)
# tensor([1.3405]) tensor([1.6046], grad_fn=<SelectBackward0>)
# tensor([3.9782]) tensor([2.3429], grad_fn=<SelectBackward0>)
# tensor([0.5103]) tensor([0.7776], grad_fn=<SelectBackward0>)
# tensor([0.3928]) tensor([0.7162], grad_fn=<SelectBackward0>)
# tensor([0.7679]) tensor([2.1407], grad_fn=<SelectBackward0>)
# tensor([1.5332]) tensor([0.5193], grad_fn=<SelectBackward0>)
# tensor([3.1586]) tensor([1.7425], grad_fn=<SelectBackward0>)
# tensor([0.9122]) tensor([1.3108], grad_fn=<SelectBackward0>)
# tensor([1.3541]) tensor([0.5342], grad_fn=<SelectBackward0>)
# tensor([0.3488]) tensor([0.4960], grad_fn=<SelectBackward0>)
# tensor([1.5712]) tensor([0.4924], grad_fn=<SelectBackward0>)
# tensor([1.4618]) tensor([0.4844], grad_fn=<SelectBackward0>)
# tensor([0.4632]) tensor([0.6968], grad_fn=<SelectBackward0>)
# tensor([0.5114]) tensor([0.7148], grad_fn=<SelectBackward0>)
# tensor([0.3034]) tensor([0.5129], grad_fn=<SelectBackward0>)
# tensor([0.2159]) tensor([0.4592], grad_fn=<SelectBackward0>)
# tensor([0.2055]) tensor([0.3903], grad_fn=<SelectBackward0>)
# tensor([0.1607]) tensor([0.3836], grad_fn=<SelectBackward0>)
# tensor([0.1718]) tensor([0.2625], grad_fn=<SelectBackward0>)
# tensor([0.1873]) tensor([0.4010], grad_fn=<SelectBackward0>)
# tensor([0.2668]) tensor([0.3356], grad_fn=<SelectBackward0>)
# tensor([0.3755]) tensor([0.9307], grad_fn=<SelectBackward0>)
# tensor([1.1411]) tensor([1.4270], grad_fn=<SelectBackward0>)
# tensor([0.6843]) tensor([0.6954], grad_fn=<SelectBackward0>)
# tensor([0.3017]) tensor([0.2007], grad_fn=<SelectBackward0>)
# tensor([1.9547]) tensor([2.2341], grad_fn=<SelectBackward0>)
# tensor([0.3022]) tensor([0.9422], grad_fn=<SelectBackward0>)
# tensor([1.7548]) tensor([0.7643], grad_fn=<SelectBackward0>)
# tensor([1.0397]) tensor([1.4814], grad_fn=<SelectBackward0>)
# tensor([1.2517]) tensor([0.8913], grad_fn=<SelectBackward0>)
# tensor([0.2734]) tensor([0.3154], grad_fn=<SelectBackward0>)
# tensor([0.4784]) tensor([0.5757], grad_fn=<SelectBackward0>)
# tensor([0.9900]) tensor([0.8106], grad_fn=<SelectBackward0>)
# tensor([2.2233]) tensor([1.6664], grad_fn=<SelectBackward0>)
# tensor([1.0582]) tensor([1.2447], grad_fn=<SelectBackward0>)
# tensor([0.3456]) tensor([0.8733], grad_fn=<SelectBackward0>)
# tensor([0.5393]) tensor([0.9454], grad_fn=<SelectBackward0>)
# tensor([1.3223]) tensor([1.1651], grad_fn=<SelectBackward0>)
# tensor([0.7666]) tensor([0.6173], grad_fn=<SelectBackward0>)
# tensor([1.8038]) tensor([1.5596], grad_fn=<SelectBackward0>)
# tensor([2.3857]) tensor([2.5651], grad_fn=<SelectBackward0>)
# tensor([0.2826]) tensor([0.4578], grad_fn=<SelectBackward0>)
# tensor([1.1063]) tensor([1.1172], grad_fn=<SelectBackward0>)
# tensor([0.5431]) tensor([2.9983], grad_fn=<SelectBackward0>)
# tensor([1.0980]) tensor([0.5867], grad_fn=<SelectBackward0>)
# tensor([0.3431]) tensor([1.0558], grad_fn=<SelectBackward0>)
# tensor([1.5166]) tensor([1.8182], grad_fn=<SelectBackward0>)
# tensor([0.8261]) tensor([0.5838], grad_fn=<SelectBackward0>)
# tensor([2.7053]) tensor([2.1818], grad_fn=<SelectBackward0>)
# tensor([0.8102]) tensor([0.8968], grad_fn=<SelectBackward0>)
# tensor([1.2882]) tensor([0.6812], grad_fn=<SelectBackward0>)
# tensor([0.3690]) tensor([0.6637], grad_fn=<SelectBackward0>)
# tensor([0.3567]) tensor([1.3457], grad_fn=<SelectBackward0>)
# tensor([0.4401]) tensor([0.7018], grad_fn=<SelectBackward0>)
# tensor([1.3535]) tensor([1.1911], grad_fn=<SelectBackward0>)
# tensor([0.8910]) tensor([2.3249], grad_fn=<SelectBackward0>)
# tensor([0.2679]) tensor([0.6561], grad_fn=<SelectBackward0>)
# tensor([0.4002]) tensor([1.2038], grad_fn=<SelectBackward0>)
# tensor([2.1553]) tensor([1.7889], grad_fn=<SelectBackward0>)
# tensor([1.6487]) tensor([0.7853], grad_fn=<SelectBackward0>)
# tensor([0.4262]) tensor([1.4543], grad_fn=<SelectBackward0>)
# tensor([1.7996]) tensor([1.8078], grad_fn=<SelectBackward0>)
# tensor([0.3917]) tensor([0.7403], grad_fn=<SelectBackward0>)
# Validating: 0it [00:00, ?it/s]
# tensor([1.5841]) tensor([1.5473])
# tensor([0.7418]) tensor([1.5083])
# tensor([0.4031]) tensor([0.4896])
# tensor([1.5727]) tensor([1.5501])
# tensor([0.4598]) tensor([0.6722])
# tensor([0.3609]) tensor([0.9674])
# tensor([0.8862]) tensor([1.6039])
# tensor([0.6603]) tensor([1.4444])
# tensor([0.3223]) tensor([0.5773])
# tensor([1.4837]) tensor([1.4765])
# tensor([0.3734]) tensor([0.5854])
# tensor([1.5351]) tensor([0.8131])
# tensor([0.5969]) tensor([0.5457])
# tensor([0.3928]) tensor([0.6879])
# tensor([3.0504]) tensor([1.5497])
# tensor([0.2807]) tensor([0.5743])
# tensor([1.8418]) tensor([2.0490])
# tensor([0.3923]) tensor([0.7196])
# tensor([0.7017]) tensor([0.6377])
# tensor([0.2618]) tensor([0.6387])
# tensor([0.2907]) tensor([0.5480])
# tensor([0.3284]) tensor([1.0083])
# tensor([0.3462]) tensor([0.8965])
# tensor([1.0652]) tensor([2.1559])
# tensor([0.5058]) tensor([0.6576])
# tensor([1.7689]) tensor([1.9189])
# tensor([1.4982]) tensor([2.5549])
# tensor([0.8277]) tensor([1.3087])
# tensor([0.3212]) tensor([0.8483])
# tensor([0.4049]) tensor([0.5434])
# tensor([1.1356]) tensor([0.7890])
# tensor([0.9091]) tensor([0.7846])
# tensor([1.0740]) tensor([1.0398])
# tensor([0.3086]) tensor([0.6499])
# tensor([1.2093]) tensor([0.9762])
# tensor([1.2882]) tensor([1.9532])
# tensor([0.3483]) tensor([0.6203])
# tensor([2.4853]) tensor([2.3983])
# tensor([1.4589]) tensor([1.3526])
# tensor([0.4760]) tensor([0.5684])
# tensor([0.7877]) tensor([0.6301])
# tensor([1.1403]) tensor([1.1787])
# tensor([0.6107]) tensor([0.6140])
# tensor([1.4034]) tensor([1.2140])
# tensor([1.7050]) tensor([1.6077])
# tensor([0.5727]) tensor([0.4870])
# tensor([1.7107]) tensor([1.6803])
# tensor([2.0344]) tensor([2.5705])
# tensor([1.6150]) tensor([0.4166])
# tensor([0.4084]) tensor([0.4703])
# tensor([0.2961]) tensor([0.4993])
# tensor([2.9658]) tensor([1.9999])
# tensor([1.8160]) tensor([1.7737])
# tensor([1.4021]) tensor([1.2155])
# tensor([3.3260]) tensor([2.3724], grad_fn=<SelectBackward0>)
# tensor([1.6982]) tensor([2.1890], grad_fn=<SelectBackward0>)
# tensor([2.5357]) tensor([1.7222], grad_fn=<SelectBackward0>)
# tensor([1.4591]) tensor([1.5154], grad_fn=<SelectBackward0>)
# tensor([1.3605]) tensor([1.1506], grad_fn=<SelectBackward0>)
# tensor([2.6555]) tensor([2.2184], grad_fn=<SelectBackward0>)
# tensor([1.6331]) tensor([0.7858], grad_fn=<SelectBackward0>)
# tensor([1.8474]) tensor([1.3476], grad_fn=<SelectBackward0>)
# tensor([1.5726]) tensor([1.8985], grad_fn=<SelectBackward0>)
# tensor([2.5464]) tensor([2.0278], grad_fn=<SelectBackward0>)
# tensor([0.3206]) tensor([0.4961], grad_fn=<SelectBackward0>)
# tensor([2.5486]) tensor([2.5407], grad_fn=<SelectBackward0>)
# tensor([0.3284]) tensor([0.3911], grad_fn=<SelectBackward0>)
# tensor([0.2797]) tensor([0.4759], grad_fn=<SelectBackward0>)
# tensor([0.2694]) tensor([0.4587], grad_fn=<SelectBackward0>)
# tensor([1.4053]) tensor([1.2612], grad_fn=<SelectBackward0>)
# tensor([0.3082]) tensor([0.4034], grad_fn=<SelectBackward0>)
# tensor([3.0984]) tensor([2.9178], grad_fn=<SelectBackward0>)
# tensor([0.5428]) tensor([0.4274], grad_fn=<SelectBackward0>)
# tensor([0.3137]) tensor([0.5884], grad_fn=<SelectBackward0>)
# tensor([1.4110]) tensor([2.9967], grad_fn=<SelectBackward0>)
# tensor([0.2628]) tensor([0.7047], grad_fn=<SelectBackward0>)
# tensor([0.3115]) tensor([0.4218], grad_fn=<SelectBackward0>)
# tensor([1.2647]) tensor([1.7473], grad_fn=<SelectBackward0>)
# tensor([0.3944]) tensor([0.6436], grad_fn=<SelectBackward0>)
# tensor([0.2822]) tensor([1.1874], grad_fn=<SelectBackward0>)
# tensor([2.2957]) tensor([0.4300], grad_fn=<SelectBackward0>)
# tensor([0.4085]) tensor([0.4605], grad_fn=<SelectBackward0>)
# tensor([0.8342]) tensor([0.4401], grad_fn=<SelectBackward0>)
# tensor([1.9203]) tensor([1.9715], grad_fn=<SelectBackward0>)
# tensor([0.2953]) tensor([0.4872], grad_fn=<SelectBackward0>)
# tensor([3.7925]) tensor([1.9496], grad_fn=<SelectBackward0>)
# tensor([1.1968]) tensor([2.8445], grad_fn=<SelectBackward0>)
# tensor([0.1934]) tensor([0.3753], grad_fn=<SelectBackward0>)
# tensor([0.1710]) tensor([0.9243], grad_fn=<SelectBackward0>)
# tensor([0.5834]) tensor([0.5653], grad_fn=<SelectBackward0>)
# tensor([0.3091]) tensor([0.4337], grad_fn=<SelectBackward0>)
# tensor([0.2811]) tensor([0.2690], grad_fn=<SelectBackward0>)
# tensor([1.2429]) tensor([0.9707], grad_fn=<SelectBackward0>)
# tensor([0.4517]) tensor([0.4429], grad_fn=<SelectBackward0>)
# tensor([1.1163]) tensor([0.6887], grad_fn=<SelectBackward0>)
# tensor([0.3509]) tensor([1.5445], grad_fn=<SelectBackward0>)
# tensor([0.4950]) tensor([0.7020], grad_fn=<SelectBackward0>)
# tensor([0.2410]) tensor([0.4801], grad_fn=<SelectBackward0>)
# tensor([0.1641]) tensor([0.3030], grad_fn=<SelectBackward0>)
# tensor([1.3424]) tensor([0.3441], grad_fn=<SelectBackward0>)
# tensor([0.1685]) tensor([0.3085], grad_fn=<SelectBackward0>)
# tensor([1.6486]) tensor([2.0735], grad_fn=<SelectBackward0>)
# tensor([0.1573]) tensor([0.4760], grad_fn=<SelectBackward0>)
# tensor([0.2316]) tensor([0.1900], grad_fn=<SelectBackward0>)
# tensor([3.3181]) tensor([2.2578], grad_fn=<SelectBackward0>)
# tensor([1.4560]) tensor([0.4890], grad_fn=<SelectBackward0>)
# tensor([0.3492]) tensor([0.6366], grad_fn=<SelectBackward0>)
# tensor([0.8861]) tensor([1.4209], grad_fn=<SelectBackward0>)
# tensor([1.2007]) tensor([0.4384], grad_fn=<SelectBackward0>)
# tensor([0.5175]) tensor([0.5010], grad_fn=<SelectBackward0>)
# tensor([1.3191]) tensor([1.7236], grad_fn=<SelectBackward0>)
# tensor([0.3142]) tensor([0.5181], grad_fn=<SelectBackward0>)
# tensor([0.3592]) tensor([0.2834], grad_fn=<SelectBackward0>)
# tensor([0.2681]) tensor([0.5228], grad_fn=<SelectBackward0>)
# tensor([0.9410]) tensor([0.6286], grad_fn=<SelectBackward0>)
# tensor([1.0747]) tensor([1.2178], grad_fn=<SelectBackward0>)
# tensor([1.1946]) tensor([1.7493], grad_fn=<SelectBackward0>)
# tensor([0.8924]) tensor([0.5871], grad_fn=<SelectBackward0>)
# tensor([0.5530]) tensor([1.1877], grad_fn=<SelectBackward0>)
# tensor([3.6695]) tensor([3.3270], grad_fn=<SelectBackward0>)
# tensor([0.5998]) tensor([0.6461], grad_fn=<SelectBackward0>)
# tensor([1.0293]) tensor([0.9738], grad_fn=<SelectBackward0>)
# tensor([0.9424]) tensor([2.1122], grad_fn=<SelectBackward0>)
# tensor([0.3452]) tensor([1.1446], grad_fn=<SelectBackward0>)
# tensor([2.4636]) tensor([1.5771], grad_fn=<SelectBackward0>)
# tensor([2.2632]) tensor([2.0807], grad_fn=<SelectBackward0>)
# tensor([2.1243]) tensor([0.8490], grad_fn=<SelectBackward0>)
# tensor([1.2324]) tensor([2.0820], grad_fn=<SelectBackward0>)
# tensor([2.0730]) tensor([2.2765], grad_fn=<SelectBackward0>)
# tensor([0.8049]) tensor([1.2496], grad_fn=<SelectBackward0>)
# tensor([3.9548]) tensor([3.1296], grad_fn=<SelectBackward0>)
# tensor([1.1022]) tensor([2.7206], grad_fn=<SelectBackward0>)
# tensor([0.2763]) tensor([0.8076], grad_fn=<SelectBackward0>)
# tensor([0.3049]) tensor([1.3316], grad_fn=<SelectBackward0>)
# tensor([0.8683]) tensor([2.1370], grad_fn=<SelectBackward0>)
# tensor([0.4283]) tensor([1.2027], grad_fn=<SelectBackward0>)
# tensor([0.6106]) tensor([1.3131], grad_fn=<SelectBackward0>)
# tensor([1.3046]) tensor([2.3198], grad_fn=<SelectBackward0>)
# tensor([0.6244]) tensor([0.4777], grad_fn=<SelectBackward0>)
# tensor([0.3845]) tensor([1.0987], grad_fn=<SelectBackward0>)
# tensor([1.8439]) tensor([2.1618], grad_fn=<SelectBackward0>)
# tensor([0.8468]) tensor([0.4870], grad_fn=<SelectBackward0>)
# tensor([0.3446]) tensor([0.9670], grad_fn=<SelectBackward0>)
# tensor([1.4109]) tensor([2.0334], grad_fn=<SelectBackward0>)
# tensor([0.3475]) tensor([0.5733], grad_fn=<SelectBackward0>)
# tensor([1.5377]) tensor([1.4771], grad_fn=<SelectBackward0>)
# tensor([1.7076]) tensor([3.0388], grad_fn=<SelectBackward0>)
# tensor([0.3269]) tensor([0.6182], grad_fn=<SelectBackward0>)
# tensor([0.5930]) tensor([0.9439], grad_fn=<SelectBackward0>)
# tensor([0.8152]) tensor([1.7402], grad_fn=<SelectBackward0>)
# tensor([0.7317]) tensor([0.7413], grad_fn=<SelectBackward0>)
# tensor([1.3405]) tensor([1.6272], grad_fn=<SelectBackward0>)
# tensor([3.9782]) tensor([2.3306], grad_fn=<SelectBackward0>)
# tensor([0.5103]) tensor([0.6814], grad_fn=<SelectBackward0>)
# tensor([0.3928]) tensor([0.6837], grad_fn=<SelectBackward0>)
# tensor([0.7679]) tensor([2.2648], grad_fn=<SelectBackward0>)
# tensor([1.5332]) tensor([0.4621], grad_fn=<SelectBackward0>)
# tensor([3.1586]) tensor([1.7809], grad_fn=<SelectBackward0>)
# tensor([0.9122]) tensor([1.2167], grad_fn=<SelectBackward0>)
# tensor([1.3541]) tensor([0.5966], grad_fn=<SelectBackward0>)
# tensor([0.3488]) tensor([0.4178], grad_fn=<SelectBackward0>)
# tensor([1.5712]) tensor([0.5256], grad_fn=<SelectBackward0>)
# tensor([1.4618]) tensor([0.4414], grad_fn=<SelectBackward0>)
# tensor([0.4632]) tensor([0.6783], grad_fn=<SelectBackward0>)
# tensor([0.5114]) tensor([0.7334], grad_fn=<SelectBackward0>)
# tensor([0.3034]) tensor([0.4855], grad_fn=<SelectBackward0>)
# tensor([0.2159]) tensor([0.4970], grad_fn=<SelectBackward0>)
# tensor([0.2055]) tensor([0.4580], grad_fn=<SelectBackward0>)
# tensor([0.1607]) tensor([0.4122], grad_fn=<SelectBackward0>)
# tensor([0.1718]) tensor([0.2857], grad_fn=<SelectBackward0>)
# tensor([0.1873]) tensor([0.3665], grad_fn=<SelectBackward0>)
# tensor([0.2668]) tensor([0.2774], grad_fn=<SelectBackward0>)
# tensor([0.3755]) tensor([0.8647], grad_fn=<SelectBackward0>)
# tensor([1.1411]) tensor([1.3945], grad_fn=<SelectBackward0>)
# tensor([0.6843]) tensor([0.6290], grad_fn=<SelectBackward0>)
# tensor([0.3017]) tensor([0.1778], grad_fn=<SelectBackward0>)
# tensor([1.9547]) tensor([2.1973], grad_fn=<SelectBackward0>)
# tensor([0.3022]) tensor([0.9670], grad_fn=<SelectBackward0>)
# tensor([1.7548]) tensor([0.8057], grad_fn=<SelectBackward0>)
# tensor([1.0397]) tensor([1.5653], grad_fn=<SelectBackward0>)
# tensor([1.2517]) tensor([0.8342], grad_fn=<SelectBackward0>)
# tensor([0.2734]) tensor([0.3428], grad_fn=<SelectBackward0>)
# tensor([0.4784]) tensor([0.6688], grad_fn=<SelectBackward0>)
# tensor([0.9900]) tensor([0.8082], grad_fn=<SelectBackward0>)
# tensor([2.2233]) tensor([1.7092], grad_fn=<SelectBackward0>)
# tensor([1.0582]) tensor([1.3489], grad_fn=<SelectBackward0>)
# tensor([0.3456]) tensor([0.8653], grad_fn=<SelectBackward0>)
# tensor([0.5393]) tensor([0.9971], grad_fn=<SelectBackward0>)
# tensor([1.3223]) tensor([1.2516], grad_fn=<SelectBackward0>)
# tensor([0.7666]) tensor([0.7804], grad_fn=<SelectBackward0>)
# tensor([1.8038]) tensor([1.6009], grad_fn=<SelectBackward0>)
# tensor([2.3857]) tensor([2.4444], grad_fn=<SelectBackward0>)
# tensor([0.2826]) tensor([0.4054], grad_fn=<SelectBackward0>)
# tensor([1.1063]) tensor([1.1155], grad_fn=<SelectBackward0>)
# tensor([0.5431]) tensor([3.0332], grad_fn=<SelectBackward0>)
# tensor([1.0980]) tensor([0.5110], grad_fn=<SelectBackward0>)
# tensor([0.3431]) tensor([1.0504], grad_fn=<SelectBackward0>)
# tensor([1.5166]) tensor([1.7689], grad_fn=<SelectBackward0>)
# tensor([0.8261]) tensor([0.5319], grad_fn=<SelectBackward0>)
# tensor([2.7053]) tensor([2.1310], grad_fn=<SelectBackward0>)
# tensor([0.8102]) tensor([0.8627], grad_fn=<SelectBackward0>)
# tensor([1.2882]) tensor([0.6422], grad_fn=<SelectBackward0>)
# tensor([0.3690]) tensor([0.6646], grad_fn=<SelectBackward0>)
# tensor([0.3567]) tensor([1.2866], grad_fn=<SelectBackward0>)
# tensor([0.4401]) tensor([0.6896], grad_fn=<SelectBackward0>)
# tensor([1.3535]) tensor([1.2830], grad_fn=<SelectBackward0>)
# tensor([0.8910]) tensor([2.1886], grad_fn=<SelectBackward0>)
# tensor([0.2679]) tensor([0.5810], grad_fn=<SelectBackward0>)
# tensor([0.4002]) tensor([1.1803], grad_fn=<SelectBackward0>)
# tensor([2.1553]) tensor([1.7534], grad_fn=<SelectBackward0>)
# tensor([1.6487]) tensor([0.7259], grad_fn=<SelectBackward0>)
# tensor([0.4262]) tensor([1.4477], grad_fn=<SelectBackward0>)
# tensor([1.7996]) tensor([1.7729], grad_fn=<SelectBackward0>)
# tensor([0.3917]) tensor([0.7339], grad_fn=<SelectBackward0>)
# Validating: 0it [00:00, ?it/s]
# tensor([1.5841]) tensor([1.5455])
# tensor([0.7418]) tensor([1.3917])
# tensor([0.4031]) tensor([0.3799])
# tensor([1.5727]) tensor([1.5093])
# tensor([0.4598]) tensor([0.6308])
# tensor([0.3609]) tensor([0.8139])
# tensor([0.8862]) tensor([1.4562])
# tensor([0.6603]) tensor([1.3090])
# tensor([0.3223]) tensor([0.4162])
# tensor([1.4837]) tensor([1.3962])
# tensor([0.3734]) tensor([0.5509])
# tensor([1.5351]) tensor([0.7521])
# tensor([0.5969]) tensor([0.5734])
# tensor([0.3928]) tensor([0.6142])
# tensor([3.0504]) tensor([1.4560])
# tensor([0.2807]) tensor([0.4665])
# tensor([1.8418]) tensor([2.0282])
# tensor([0.3923]) tensor([0.5584])
# tensor([0.7017]) tensor([0.5260])
# tensor([0.2618]) tensor([0.5466])
# tensor([0.2907]) tensor([0.4902])
# tensor([0.3284]) tensor([0.8641])
# tensor([0.3462]) tensor([0.7529])
# tensor([1.0652]) tensor([2.1279])
# tensor([0.5058]) tensor([0.6081])
# tensor([1.7689]) tensor([1.8252])
# tensor([1.4982]) tensor([2.5267])
# tensor([0.8277]) tensor([1.1192])
# tensor([0.3212]) tensor([0.7810])
# tensor([0.4049]) tensor([0.4700])
# tensor([1.1356]) tensor([0.6503])
# tensor([0.9091]) tensor([0.7851])
# tensor([1.0740]) tensor([1.0616])
# tensor([0.3086]) tensor([0.5307])
# tensor([1.2093]) tensor([0.9372])
# tensor([1.2882]) tensor([1.8325])
# tensor([0.3483]) tensor([0.5285])
# tensor([2.4853]) tensor([2.4572])
# tensor([1.4589]) tensor([1.3657])
# tensor([0.4760]) tensor([0.4916])
# tensor([0.7877]) tensor([0.6318])
# tensor([1.1403]) tensor([1.1659])
# tensor([0.6107]) tensor([0.5650])
# tensor([1.4034]) tensor([1.1901])
# tensor([1.7050]) tensor([1.6067])
# tensor([0.5727]) tensor([0.3785])
# tensor([1.7107]) tensor([1.6972])
# tensor([2.0344]) tensor([2.4829])
# tensor([1.6150]) tensor([0.3511])
# tensor([0.4084]) tensor([0.4216])
# tensor([0.2961]) tensor([0.3838])
# tensor([2.9658]) tensor([1.9192])
# tensor([1.8160]) tensor([1.8346])
# tensor([1.4021]) tensor([1.2466])
# tensor([3.3260]) tensor([2.3807], grad_fn=<SelectBackward0>)
# tensor([1.6982]) tensor([2.0762], grad_fn=<SelectBackward0>)
# tensor([2.5357]) tensor([1.8164], grad_fn=<SelectBackward0>)
# tensor([1.4591]) tensor([1.3782], grad_fn=<SelectBackward0>)
# tensor([1.3605]) tensor([1.1914], grad_fn=<SelectBackward0>)
# tensor([2.6555]) tensor([2.2398], grad_fn=<SelectBackward0>)
# tensor([1.6331]) tensor([0.6842], grad_fn=<SelectBackward0>)
# tensor([1.8474]) tensor([1.2870], grad_fn=<SelectBackward0>)
# tensor([1.5726]) tensor([2.0346], grad_fn=<SelectBackward0>)
# tensor([2.5464]) tensor([2.0975], grad_fn=<SelectBackward0>)
# tensor([0.3206]) tensor([0.4936], grad_fn=<SelectBackward0>)
# tensor([2.5486]) tensor([2.4735], grad_fn=<SelectBackward0>)
# tensor([0.3284]) tensor([0.3982], grad_fn=<SelectBackward0>)
# tensor([0.2797]) tensor([0.4630], grad_fn=<SelectBackward0>)
# tensor([0.2694]) tensor([0.4196], grad_fn=<SelectBackward0>)
# tensor([1.4053]) tensor([1.2512], grad_fn=<SelectBackward0>)
# tensor([0.3082]) tensor([0.4506], grad_fn=<SelectBackward0>)
# tensor([3.0984]) tensor([3.0517], grad_fn=<SelectBackward0>)
# tensor([0.5428]) tensor([0.4315], grad_fn=<SelectBackward0>)
# tensor([0.3137]) tensor([0.5131], grad_fn=<SelectBackward0>)
# tensor([1.4110]) tensor([2.9953], grad_fn=<SelectBackward0>)
# tensor([0.2628]) tensor([0.6870], grad_fn=<SelectBackward0>)
# tensor([0.3115]) tensor([0.4582], grad_fn=<SelectBackward0>)
# tensor([1.2647]) tensor([1.7400], grad_fn=<SelectBackward0>)
# tensor([0.3944]) tensor([0.6867], grad_fn=<SelectBackward0>)
# tensor([0.2822]) tensor([1.2227], grad_fn=<SelectBackward0>)
# tensor([2.2957]) tensor([0.4346], grad_fn=<SelectBackward0>)
# tensor([0.4085]) tensor([0.3725], grad_fn=<SelectBackward0>)
# tensor([0.8342]) tensor([0.4278], grad_fn=<SelectBackward0>)
# tensor([1.9203]) tensor([1.9568], grad_fn=<SelectBackward0>)
# tensor([0.2953]) tensor([0.4424], grad_fn=<SelectBackward0>)
# tensor([3.7925]) tensor([2.0293], grad_fn=<SelectBackward0>)
# tensor([1.1968]) tensor([2.6558], grad_fn=<SelectBackward0>)
# tensor([0.1934]) tensor([0.2901], grad_fn=<SelectBackward0>)
# tensor([0.1710]) tensor([0.8661], grad_fn=<SelectBackward0>)
# tensor([0.5834]) tensor([0.6159], grad_fn=<SelectBackward0>)
# tensor([0.3091]) tensor([0.3866], grad_fn=<SelectBackward0>)
# tensor([0.2811]) tensor([0.2500], grad_fn=<SelectBackward0>)
# tensor([1.2429]) tensor([1.0601], grad_fn=<SelectBackward0>)
# tensor([0.4517]) tensor([0.4839], grad_fn=<SelectBackward0>)
# tensor([1.1163]) tensor([0.5903], grad_fn=<SelectBackward0>)
# tensor([0.3509]) tensor([1.4783], grad_fn=<SelectBackward0>)
# tensor([0.4950]) tensor([0.7903], grad_fn=<SelectBackward0>)
# tensor([0.2410]) tensor([0.4892], grad_fn=<SelectBackward0>)
# tensor([0.1641]) tensor([0.3579], grad_fn=<SelectBackward0>)
# tensor([1.3424]) tensor([0.3488], grad_fn=<SelectBackward0>)
# tensor([0.1685]) tensor([0.2804], grad_fn=<SelectBackward0>)
# tensor([1.6486]) tensor([2.0278], grad_fn=<SelectBackward0>)
# tensor([0.1573]) tensor([0.4681], grad_fn=<SelectBackward0>)
# tensor([0.2316]) tensor([0.1667], grad_fn=<SelectBackward0>)
# tensor([3.3181]) tensor([2.1745], grad_fn=<SelectBackward0>)
# tensor([1.4560]) tensor([0.4543], grad_fn=<SelectBackward0>)
# tensor([0.3492]) tensor([0.7533], grad_fn=<SelectBackward0>)
# tensor([0.8861]) tensor([1.4834], grad_fn=<SelectBackward0>)
# tensor([1.2007]) tensor([0.4483], grad_fn=<SelectBackward0>)
# tensor([0.5175]) tensor([0.4492], grad_fn=<SelectBackward0>)
# tensor([1.3191]) tensor([1.6251], grad_fn=<SelectBackward0>)
# tensor([0.3142]) tensor([0.5016], grad_fn=<SelectBackward0>)
# tensor([0.3592]) tensor([0.2706], grad_fn=<SelectBackward0>)
# tensor([0.2681]) tensor([0.4678], grad_fn=<SelectBackward0>)
# tensor([0.9410]) tensor([0.6236], grad_fn=<SelectBackward0>)
# tensor([1.0747]) tensor([1.2727], grad_fn=<SelectBackward0>)
# tensor([1.1946]) tensor([1.5988], grad_fn=<SelectBackward0>)
# tensor([0.8924]) tensor([0.4969], grad_fn=<SelectBackward0>)
# tensor([0.5530]) tensor([1.2191], grad_fn=<SelectBackward0>)
# tensor([3.6695]) tensor([3.2798], grad_fn=<SelectBackward0>)
# tensor([0.5998]) tensor([0.5742], grad_fn=<SelectBackward0>)
# tensor([1.0293]) tensor([1.0344], grad_fn=<SelectBackward0>)
# tensor([0.9424]) tensor([2.0122], grad_fn=<SelectBackward0>)
# tensor([0.3452]) tensor([1.0795], grad_fn=<SelectBackward0>)
# tensor([2.4636]) tensor([1.6834], grad_fn=<SelectBackward0>)
# tensor([2.2632]) tensor([2.1476], grad_fn=<SelectBackward0>)
# tensor([2.1243]) tensor([0.7715], grad_fn=<SelectBackward0>)
# tensor([1.2324]) tensor([2.2030], grad_fn=<SelectBackward0>)
# tensor([2.0730]) tensor([2.2776], grad_fn=<SelectBackward0>)
# tensor([0.8049]) tensor([1.1462], grad_fn=<SelectBackward0>)
# tensor([3.9548]) tensor([3.1427], grad_fn=<SelectBackward0>)
# tensor([1.1022]) tensor([2.6756], grad_fn=<SelectBackward0>)
# tensor([0.2763]) tensor([0.7378], grad_fn=<SelectBackward0>)
# tensor([0.3049]) tensor([1.3557], grad_fn=<SelectBackward0>)
# tensor([0.8683]) tensor([2.1439], grad_fn=<SelectBackward0>)
# tensor([0.4283]) tensor([1.1502], grad_fn=<SelectBackward0>)
# tensor([0.6106]) tensor([1.2683], grad_fn=<SelectBackward0>)
# tensor([1.3046]) tensor([2.2919], grad_fn=<SelectBackward0>)
# tensor([0.6244]) tensor([0.4282], grad_fn=<SelectBackward0>)
# tensor([0.3845]) tensor([0.9818], grad_fn=<SelectBackward0>)
# tensor([1.8439]) tensor([2.0954], grad_fn=<SelectBackward0>)
# tensor([0.8468]) tensor([0.5517], grad_fn=<SelectBackward0>)
# tensor([0.3446]) tensor([0.8950], grad_fn=<SelectBackward0>)
# tensor([1.4109]) tensor([1.9659], grad_fn=<SelectBackward0>)
# tensor([0.3475]) tensor([0.5247], grad_fn=<SelectBackward0>)
# tensor([1.5377]) tensor([1.3586], grad_fn=<SelectBackward0>)
# tensor([1.7076]) tensor([3.0028], grad_fn=<SelectBackward0>)
# tensor([0.3269]) tensor([0.6742], grad_fn=<SelectBackward0>)
# tensor([0.5930]) tensor([1.0706], grad_fn=<SelectBackward0>)
# tensor([0.8152]) tensor([1.6949], grad_fn=<SelectBackward0>)
# tensor([0.7317]) tensor([0.6838], grad_fn=<SelectBackward0>)
# tensor([1.3405]) tensor([1.6011], grad_fn=<SelectBackward0>)
# tensor([3.9782]) tensor([2.2374], grad_fn=<SelectBackward0>)
# tensor([0.5103]) tensor([0.5896], grad_fn=<SelectBackward0>)
# tensor([0.3928]) tensor([0.6306], grad_fn=<SelectBackward0>)
# tensor([0.7679]) tensor([2.1501], grad_fn=<SelectBackward0>)
# tensor([1.5332]) tensor([0.4015], grad_fn=<SelectBackward0>)
# tensor([3.1586]) tensor([1.7685], grad_fn=<SelectBackward0>)
# tensor([0.9122]) tensor([1.1421], grad_fn=<SelectBackward0>)
# tensor([1.3541]) tensor([0.5666], grad_fn=<SelectBackward0>)
# tensor([0.3488]) tensor([0.4479], grad_fn=<SelectBackward0>)
# tensor([1.5712]) tensor([0.5203], grad_fn=<SelectBackward0>)
# tensor([1.4618]) tensor([0.4601], grad_fn=<SelectBackward0>)
# tensor([0.4632]) tensor([0.7727], grad_fn=<SelectBackward0>)
# tensor([0.5114]) tensor([0.8226], grad_fn=<SelectBackward0>)
# tensor([0.3034]) tensor([0.5227], grad_fn=<SelectBackward0>)
# tensor([0.2159]) tensor([0.5227], grad_fn=<SelectBackward0>)
# tensor([0.2055]) tensor([0.4904], grad_fn=<SelectBackward0>)
# tensor([0.1607]) tensor([0.4236], grad_fn=<SelectBackward0>)
# tensor([0.1718]) tensor([0.3261], grad_fn=<SelectBackward0>)
# tensor([0.1873]) tensor([0.2578], grad_fn=<SelectBackward0>)
# tensor([0.2668]) tensor([0.1894], grad_fn=<SelectBackward0>)
# tensor([0.3755]) tensor([0.8319], grad_fn=<SelectBackward0>)
# tensor([1.1411]) tensor([1.2947], grad_fn=<SelectBackward0>)
# tensor([0.6843]) tensor([0.6565], grad_fn=<SelectBackward0>)
# tensor([0.3017]) tensor([0.1293], grad_fn=<SelectBackward0>)
# tensor([1.9547]) tensor([2.1435], grad_fn=<SelectBackward0>)
# tensor([0.3022]) tensor([0.9233], grad_fn=<SelectBackward0>)
# tensor([1.7548]) tensor([0.8161], grad_fn=<SelectBackward0>)
# tensor([1.0397]) tensor([1.5117], grad_fn=<SelectBackward0>)
# tensor([1.2517]) tensor([0.9141], grad_fn=<SelectBackward0>)
# tensor([0.2734]) tensor([0.4010], grad_fn=<SelectBackward0>)
# tensor([0.4784]) tensor([0.6699], grad_fn=<SelectBackward0>)
# tensor([0.9900]) tensor([0.8541], grad_fn=<SelectBackward0>)
# tensor([2.2233]) tensor([1.8055], grad_fn=<SelectBackward0>)
# tensor([1.0582]) tensor([1.2149], grad_fn=<SelectBackward0>)
# tensor([0.3456]) tensor([0.8392], grad_fn=<SelectBackward0>)
# tensor([0.5393]) tensor([1.0622], grad_fn=<SelectBackward0>)
# tensor([1.3223]) tensor([1.1441], grad_fn=<SelectBackward0>)
# tensor([0.7666]) tensor([0.9687], grad_fn=<SelectBackward0>)
# tensor([1.8038]) tensor([1.6759], grad_fn=<SelectBackward0>)
# tensor([2.3857]) tensor([2.4906], grad_fn=<SelectBackward0>)
# tensor([0.2826]) tensor([0.3645], grad_fn=<SelectBackward0>)
# tensor([1.1063]) tensor([1.0973], grad_fn=<SelectBackward0>)
# tensor([0.5431]) tensor([3.0060], grad_fn=<SelectBackward0>)
# tensor([1.0980]) tensor([0.5016], grad_fn=<SelectBackward0>)
# tensor([0.3431]) tensor([1.0251], grad_fn=<SelectBackward0>)
# tensor([1.5166]) tensor([1.7099], grad_fn=<SelectBackward0>)
# tensor([0.8261]) tensor([0.5646], grad_fn=<SelectBackward0>)
# tensor([2.7053]) tensor([2.2540], grad_fn=<SelectBackward0>)
# tensor([0.8102]) tensor([0.7628], grad_fn=<SelectBackward0>)
# tensor([1.2882]) tensor([0.6167], grad_fn=<SelectBackward0>)
# tensor([0.3690]) tensor([0.5607], grad_fn=<SelectBackward0>)
# tensor([0.3567]) tensor([1.2377], grad_fn=<SelectBackward0>)
# tensor([0.4401]) tensor([0.6234], grad_fn=<SelectBackward0>)
# tensor([1.3535]) tensor([1.4434], grad_fn=<SelectBackward0>)
# tensor([0.8910]) tensor([2.1790], grad_fn=<SelectBackward0>)
# tensor([0.2679]) tensor([0.5738], grad_fn=<SelectBackward0>)
# tensor([0.4002]) tensor([1.1644], grad_fn=<SelectBackward0>)
# tensor([2.1553]) tensor([1.7421], grad_fn=<SelectBackward0>)
# tensor([1.6487]) tensor([0.7491], grad_fn=<SelectBackward0>)
# tensor([0.4262]) tensor([1.4509], grad_fn=<SelectBackward0>)
# tensor([1.7996]) tensor([1.8626], grad_fn=<SelectBackward0>)
# tensor([0.3917]) tensor([0.7800], grad_fn=<SelectBackward0>)
# Validating: 0it [00:00, ?it/s]
# tensor([1.5841]) tensor([1.5146])
# tensor([0.7418]) tensor([1.3350])
# tensor([0.4031]) tensor([0.3174])
# tensor([1.5727]) tensor([1.5186])
# tensor([0.4598]) tensor([0.6582])
# tensor([0.3609]) tensor([0.6681])
# tensor([0.8862]) tensor([1.3880])
# tensor([0.6603]) tensor([1.2664])
# tensor([0.3223]) tensor([0.3479])
# tensor([1.4837]) tensor([1.3816])
# tensor([0.3734]) tensor([0.5941])
# tensor([1.5351]) tensor([0.7939])
# tensor([0.5969]) tensor([0.7357])
# tensor([0.3928]) tensor([0.6125])
# tensor([3.0504]) tensor([1.4606])
# tensor([0.2807]) tensor([0.5076])
# tensor([1.8418]) tensor([2.0297])
# tensor([0.3923]) tensor([0.5331])
# tensor([0.7017]) tensor([0.5142])
# tensor([0.2618]) tensor([0.5567])
# tensor([0.2907]) tensor([0.5250])
# tensor([0.3284]) tensor([0.8317])
# tensor([0.3462]) tensor([0.7456])
# tensor([1.0652]) tensor([2.2192])
# tensor([0.5058]) tensor([0.6690])
# tensor([1.7689]) tensor([1.8089])
# tensor([1.4982]) tensor([2.4958])
# tensor([0.8277]) tensor([1.0764])
# tensor([0.3212]) tensor([0.7637])
# tensor([0.4049]) tensor([0.4234])
# tensor([1.1356]) tensor([0.6947])
# tensor([0.9091]) tensor([0.8126])
# tensor([1.0740]) tensor([1.1712])
# tensor([0.3086]) tensor([0.5527])
# tensor([1.2093]) tensor([0.9985])
# tensor([1.2882]) tensor([1.8612])
# tensor([0.3483]) tensor([0.6229])
# tensor([2.4853]) tensor([2.4274])
# tensor([1.4589]) tensor([1.3800])
# tensor([0.4760]) tensor([0.5625])
# tensor([0.7877]) tensor([0.7557])
# tensor([1.1403]) tensor([1.1573])
# tensor([0.6107]) tensor([0.6457])
# tensor([1.4034]) tensor([1.1619])
# tensor([1.7050]) tensor([1.5534])
# tensor([0.5727]) tensor([0.4979])
# tensor([1.7107]) tensor([1.7878])
# tensor([2.0344]) tensor([2.4155])
# tensor([1.6150]) tensor([0.4068])
# tensor([0.4084]) tensor([0.4222])
# tensor([0.2961]) tensor([0.3028])
# tensor([2.9658]) tensor([1.8949])
# tensor([1.8160]) tensor([1.8819])
# tensor([1.4021]) tensor([1.3336])
# tensor([3.3260]) tensor([2.4205], grad_fn=<SelectBackward0>)
# tensor([1.6982]) tensor([2.0163], grad_fn=<SelectBackward0>)
# tensor([2.5357]) tensor([1.9753], grad_fn=<SelectBackward0>)
# tensor([1.4591]) tensor([1.2366], grad_fn=<SelectBackward0>)
# tensor([1.3605]) tensor([1.3177], grad_fn=<SelectBackward0>)
# tensor([2.6555]) tensor([2.3304], grad_fn=<SelectBackward0>)
# tensor([1.6331]) tensor([0.6407], grad_fn=<SelectBackward0>)
# tensor([1.8474]) tensor([1.3030], grad_fn=<SelectBackward0>)
# tensor([1.5726]) tensor([2.1880], grad_fn=<SelectBackward0>)
# tensor([2.5464]) tensor([2.0673], grad_fn=<SelectBackward0>)
# tensor([0.3206]) tensor([0.5913], grad_fn=<SelectBackward0>)
# tensor([2.5486]) tensor([2.4108], grad_fn=<SelectBackward0>)
# tensor([0.3284]) tensor([0.3277], grad_fn=<SelectBackward0>)
# tensor([0.2797]) tensor([0.4259], grad_fn=<SelectBackward0>)
# tensor([0.2694]) tensor([0.3774], grad_fn=<SelectBackward0>)
# tensor([1.4053]) tensor([1.1701], grad_fn=<SelectBackward0>)
# tensor([0.3082]) tensor([0.4527], grad_fn=<SelectBackward0>)
# tensor([3.0984]) tensor([3.1230], grad_fn=<SelectBackward0>)
# tensor([0.5428]) tensor([0.4440], grad_fn=<SelectBackward0>)
# tensor([0.3137]) tensor([0.4997], grad_fn=<SelectBackward0>)
# tensor([1.4110]) tensor([2.9582], grad_fn=<SelectBackward0>)
# tensor([0.2628]) tensor([0.6201], grad_fn=<SelectBackward0>)
# tensor([0.3115]) tensor([0.5059], grad_fn=<SelectBackward0>)
# tensor([1.2647]) tensor([1.6785], grad_fn=<SelectBackward0>)
# tensor([0.3944]) tensor([0.6994], grad_fn=<SelectBackward0>)
# tensor([0.2822]) tensor([1.2667], grad_fn=<SelectBackward0>)
# tensor([2.2957]) tensor([0.4944], grad_fn=<SelectBackward0>)
# tensor([0.4085]) tensor([0.3985], grad_fn=<SelectBackward0>)
# tensor([0.8342]) tensor([0.4828], grad_fn=<SelectBackward0>)
# tensor([1.9203]) tensor([1.9356], grad_fn=<SelectBackward0>)
# tensor([0.2953]) tensor([0.4851], grad_fn=<SelectBackward0>)
# tensor([3.7925]) tensor([2.0083], grad_fn=<SelectBackward0>)
# tensor([1.1968]) tensor([2.6213], grad_fn=<SelectBackward0>)
# tensor([0.1934]) tensor([0.3517], grad_fn=<SelectBackward0>)
# tensor([0.1710]) tensor([0.8044], grad_fn=<SelectBackward0>)
# tensor([0.5834]) tensor([0.6158], grad_fn=<SelectBackward0>)
# tensor([0.3091]) tensor([0.3643], grad_fn=<SelectBackward0>)
# tensor([0.2811]) tensor([0.2124], grad_fn=<SelectBackward0>)
# tensor([1.2429]) tensor([1.1086], grad_fn=<SelectBackward0>)
# tensor([0.4517]) tensor([0.4938], grad_fn=<SelectBackward0>)
# tensor([1.1163]) tensor([0.5701], grad_fn=<SelectBackward0>)
# tensor([0.3509]) tensor([1.4202], grad_fn=<SelectBackward0>)
# tensor([0.4950]) tensor([0.7564], grad_fn=<SelectBackward0>)
# tensor([0.2410]) tensor([0.4985], grad_fn=<SelectBackward0>)
# tensor([0.1641]) tensor([0.3279], grad_fn=<SelectBackward0>)
# tensor([1.3424]) tensor([0.3359], grad_fn=<SelectBackward0>)
# tensor([0.1685]) tensor([0.2580], grad_fn=<SelectBackward0>)
# tensor([1.6486]) tensor([2.0583], grad_fn=<SelectBackward0>)
# tensor([0.1573]) tensor([0.4917], grad_fn=<SelectBackward0>)
# tensor([0.2316]) tensor([0.1497], grad_fn=<SelectBackward0>)
# tensor([3.3181]) tensor([2.1295], grad_fn=<SelectBackward0>)
# tensor([1.4560]) tensor([0.5130], grad_fn=<SelectBackward0>)
# tensor([0.3492]) tensor([0.7509], grad_fn=<SelectBackward0>)
# tensor([0.8861]) tensor([1.4897], grad_fn=<SelectBackward0>)
# tensor([1.2007]) tensor([0.4863], grad_fn=<SelectBackward0>)
# tensor([0.5175]) tensor([0.4400], grad_fn=<SelectBackward0>)
# tensor([1.3191]) tensor([1.6159], grad_fn=<SelectBackward0>)
# tensor([0.3142]) tensor([0.4989], grad_fn=<SelectBackward0>)
# tensor([0.3592]) tensor([0.2585], grad_fn=<SelectBackward0>)
# tensor([0.2681]) tensor([0.4504], grad_fn=<SelectBackward0>)
# tensor([0.9410]) tensor([0.6439], grad_fn=<SelectBackward0>)
# tensor([1.0747]) tensor([1.2309], grad_fn=<SelectBackward0>)
# tensor([1.1946]) tensor([1.5453], grad_fn=<SelectBackward0>)
# tensor([0.8924]) tensor([0.4637], grad_fn=<SelectBackward0>)
# tensor([0.5530]) tensor([1.1940], grad_fn=<SelectBackward0>)
# tensor([3.6695]) tensor([3.2133], grad_fn=<SelectBackward0>)
# tensor([0.5998]) tensor([0.5479], grad_fn=<SelectBackward0>)
# tensor([1.0293]) tensor([0.9892], grad_fn=<SelectBackward0>)
# tensor([0.9424]) tensor([1.9903], grad_fn=<SelectBackward0>)
# tensor([0.3452]) tensor([1.1063], grad_fn=<SelectBackward0>)
# tensor([2.4636]) tensor([1.6981], grad_fn=<SelectBackward0>)
# tensor([2.2632]) tensor([2.1939], grad_fn=<SelectBackward0>)
# tensor([2.1243]) tensor([0.8376], grad_fn=<SelectBackward0>)
# tensor([1.2324]) tensor([2.2207], grad_fn=<SelectBackward0>)
# tensor([2.0730]) tensor([2.3234], grad_fn=<SelectBackward0>)
# tensor([0.8049]) tensor([1.1904], grad_fn=<SelectBackward0>)
# tensor([3.9548]) tensor([3.0967], grad_fn=<SelectBackward0>)
# tensor([1.1022]) tensor([2.6674], grad_fn=<SelectBackward0>)
# tensor([0.2763]) tensor([0.7168], grad_fn=<SelectBackward0>)
# tensor([0.3049]) tensor([1.3554], grad_fn=<SelectBackward0>)
# tensor([0.8683]) tensor([2.2074], grad_fn=<SelectBackward0>)
# tensor([0.4283]) tensor([1.0933], grad_fn=<SelectBackward0>)
# tensor([0.6106]) tensor([1.2181], grad_fn=<SelectBackward0>)
# tensor([1.3046]) tensor([2.3127], grad_fn=<SelectBackward0>)
# tensor([0.6244]) tensor([0.4839], grad_fn=<SelectBackward0>)
# tensor([0.3845]) tensor([0.9938], grad_fn=<SelectBackward0>)
# tensor([1.8439]) tensor([2.1318], grad_fn=<SelectBackward0>)
# tensor([0.8468]) tensor([0.5558], grad_fn=<SelectBackward0>)
# tensor([0.3446]) tensor([0.8429], grad_fn=<SelectBackward0>)
# tensor([1.4109]) tensor([1.9722], grad_fn=<SelectBackward0>)
# tensor([0.3475]) tensor([0.5921], grad_fn=<SelectBackward0>)
# tensor([1.5377]) tensor([1.3124], grad_fn=<SelectBackward0>)
# tensor([1.7076]) tensor([2.9548], grad_fn=<SelectBackward0>)
# tensor([0.3269]) tensor([0.6675], grad_fn=<SelectBackward0>)
# tensor([0.5930]) tensor([1.0466], grad_fn=<SelectBackward0>)
# tensor([0.8152]) tensor([1.7112], grad_fn=<SelectBackward0>)
# tensor([0.7317]) tensor([0.6870], grad_fn=<SelectBackward0>)
# tensor([1.3405]) tensor([1.6114], grad_fn=<SelectBackward0>)
# tensor([3.9782]) tensor([2.1541], grad_fn=<SelectBackward0>)
# tensor([0.5103]) tensor([0.6201], grad_fn=<SelectBackward0>)
# tensor([0.3928]) tensor([0.6029], grad_fn=<SelectBackward0>)
# tensor([0.7679]) tensor([2.1715], grad_fn=<SelectBackward0>)
# tensor([1.5332]) tensor([0.3694], grad_fn=<SelectBackward0>)
# tensor([3.1586]) tensor([1.8057], grad_fn=<SelectBackward0>)
# tensor([0.9122]) tensor([1.1735], grad_fn=<SelectBackward0>)
# tensor([1.3541]) tensor([0.5176], grad_fn=<SelectBackward0>)
# tensor([0.3488]) tensor([0.4230], grad_fn=<SelectBackward0>)
# tensor([1.5712]) tensor([0.3930], grad_fn=<SelectBackward0>)
# tensor([1.4618]) tensor([0.3967], grad_fn=<SelectBackward0>)
# tensor([0.4632]) tensor([0.7821], grad_fn=<SelectBackward0>)
# tensor([0.5114]) tensor([0.8059], grad_fn=<SelectBackward0>)
# tensor([0.3034]) tensor([0.4813], grad_fn=<SelectBackward0>)
# tensor([0.2159]) tensor([0.4640], grad_fn=<SelectBackward0>)
# tensor([0.2055]) tensor([0.4584], grad_fn=<SelectBackward0>)
# tensor([0.1607]) tensor([0.4279], grad_fn=<SelectBackward0>)
# tensor([0.1718]) tensor([0.3632], grad_fn=<SelectBackward0>)
# tensor([0.1873]) tensor([0.3942], grad_fn=<SelectBackward0>)
# tensor([0.2668]) tensor([0.2832], grad_fn=<SelectBackward0>)
# tensor([0.3755]) tensor([0.8959], grad_fn=<SelectBackward0>)
# tensor([1.1411]) tensor([1.2324], grad_fn=<SelectBackward0>)
# tensor([0.6843]) tensor([0.6455], grad_fn=<SelectBackward0>)
# tensor([0.3017]) tensor([0.1450], grad_fn=<SelectBackward0>)
# tensor([1.9547]) tensor([2.2245], grad_fn=<SelectBackward0>)
# tensor([0.3022]) tensor([0.8852], grad_fn=<SelectBackward0>)
# tensor([1.7548]) tensor([0.8412], grad_fn=<SelectBackward0>)
# tensor([1.0397]) tensor([1.5518], grad_fn=<SelectBackward0>)
# tensor([1.2517]) tensor([0.8677], grad_fn=<SelectBackward0>)
# tensor([0.2734]) tensor([0.3821], grad_fn=<SelectBackward0>)
# tensor([0.4784]) tensor([0.6843], grad_fn=<SelectBackward0>)
# tensor([0.9900]) tensor([0.8675], grad_fn=<SelectBackward0>)
# tensor([2.2233]) tensor([1.8397], grad_fn=<SelectBackward0>)
# tensor([1.0582]) tensor([1.1888], grad_fn=<SelectBackward0>)
# tensor([0.3456]) tensor([0.8363], grad_fn=<SelectBackward0>)
# tensor([0.5393]) tensor([1.0227], grad_fn=<SelectBackward0>)
# tensor([1.3223]) tensor([1.1952], grad_fn=<SelectBackward0>)
# tensor([0.7666]) tensor([1.1367], grad_fn=<SelectBackward0>)
# tensor([1.8038]) tensor([1.7404], grad_fn=<SelectBackward0>)
# tensor([2.3857]) tensor([2.5875], grad_fn=<SelectBackward0>)
# tensor([0.2826]) tensor([0.3118], grad_fn=<SelectBackward0>)
# tensor([1.1063]) tensor([1.0293], grad_fn=<SelectBackward0>)
# tensor([0.5431]) tensor([2.9603], grad_fn=<SelectBackward0>)
# tensor([1.0980]) tensor([0.5987], grad_fn=<SelectBackward0>)
# tensor([0.3431]) tensor([0.9761], grad_fn=<SelectBackward0>)
# tensor([1.5166]) tensor([1.8960], grad_fn=<SelectBackward0>)
# tensor([0.8261]) tensor([0.6533], grad_fn=<SelectBackward0>)
# tensor([2.7053]) tensor([2.2058], grad_fn=<SelectBackward0>)
# tensor([0.8102]) tensor([0.7451], grad_fn=<SelectBackward0>)
# tensor([1.2882]) tensor([0.7183], grad_fn=<SelectBackward0>)
# tensor([0.3690]) tensor([0.5919], grad_fn=<SelectBackward0>)
# tensor([0.3567]) tensor([1.1731], grad_fn=<SelectBackward0>)
# tensor([0.4401]) tensor([0.5842], grad_fn=<SelectBackward0>)
# tensor([1.3535]) tensor([1.4711], grad_fn=<SelectBackward0>)
# tensor([0.8910]) tensor([2.1601], grad_fn=<SelectBackward0>)
# tensor([0.2679]) tensor([0.4266], grad_fn=<SelectBackward0>)
# tensor([0.4002]) tensor([1.0991], grad_fn=<SelectBackward0>)
# tensor([2.1553]) tensor([1.6850], grad_fn=<SelectBackward0>)
# tensor([1.6487]) tensor([0.8459], grad_fn=<SelectBackward0>)
# tensor([0.4262]) tensor([1.4214], grad_fn=<SelectBackward0>)
# tensor([1.7996]) tensor([1.7956], grad_fn=<SelectBackward0>)
# tensor([0.3917]) tensor([0.7929], grad_fn=<SelectBackward0>)
# Validating: 0it [00:00, ?it/s]
# tensor([1.5841]) tensor([1.5437])
# tensor([0.7418]) tensor([1.3096])
# tensor([0.4031]) tensor([0.2668])
# tensor([1.5727]) tensor([1.5141])
# tensor([0.4598]) tensor([0.7210])
# tensor([0.3609]) tensor([0.5642])
# tensor([0.8862]) tensor([1.3438])
# tensor([0.6603]) tensor([1.2582])
# tensor([0.3223]) tensor([0.2337])
# tensor([1.4837]) tensor([1.4086])
# tensor([0.3734]) tensor([0.6157])
# tensor([1.5351]) tensor([0.8595])
# tensor([0.5969]) tensor([0.8270])
# tensor([0.3928]) tensor([0.6548])
# tensor([3.0504]) tensor([1.5029])
# tensor([0.2807]) tensor([0.4392])
# tensor([1.8418]) tensor([2.0165])
# tensor([0.3923]) tensor([0.2858])
# tensor([0.7017]) tensor([0.3737])
# tensor([0.2618]) tensor([0.4901])
# tensor([0.2907]) tensor([0.4199])
# tensor([0.3284]) tensor([0.7411])
# tensor([0.3462]) tensor([0.5721])
# tensor([1.0652]) tensor([2.1758])
# tensor([0.5058]) tensor([0.6062])
# tensor([1.7689]) tensor([1.8158])
# tensor([1.4982]) tensor([2.5188])
# tensor([0.8277]) tensor([0.9262])
# tensor([0.3212]) tensor([0.7021])
# tensor([0.4049]) tensor([0.3488])
# tensor([1.1356]) tensor([0.5454])
# tensor([0.9091]) tensor([0.7921])
# tensor([1.0740]) tensor([1.1431])
# tensor([0.3086]) tensor([0.3877])
# tensor([1.2093]) tensor([0.9577])
# tensor([1.2882]) tensor([1.9369])
# tensor([0.3483]) tensor([0.5241])
# tensor([2.4853]) tensor([2.5626])
# tensor([1.4589]) tensor([1.2627])
# tensor([0.4760]) tensor([0.4635])
# tensor([0.7877]) tensor([0.7532])
# tensor([1.1403]) tensor([1.1583])
# tensor([0.6107]) tensor([0.6074])
# tensor([1.4034]) tensor([1.1434])
# tensor([1.7050]) tensor([1.5001])
# tensor([0.5727]) tensor([0.3111])
# tensor([1.7107]) tensor([1.8831])
# tensor([2.0344]) tensor([2.4799])
# tensor([1.6150]) tensor([0.3230])
# tensor([0.4084]) tensor([0.3010])
# tensor([0.2961]) tensor([0.1678])
# tensor([2.9658]) tensor([1.8832])
# tensor([1.8160]) tensor([1.9241])
# tensor([1.4021]) tensor([1.3845])
